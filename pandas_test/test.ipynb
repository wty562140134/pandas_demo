# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt, mpld3

# %%
d = [{'a': 1, 'b': 2, 'c': 3}]
pd.DataFrame(d)
# Out:
# C:\Users\LKJH\AppData\Local\Temp\ipykernel_19792\3326289017.py:17: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for key, val in df.iteritems():

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])
plt.plot(xpoints, ypoints, 'r--o')
fig = plt.figure()
html_fragment = mpld3.fig_to_html(fig, figid='fig1')
mpld3.show(fig)
# html_fragment = mpld3.fig_to_html(fig, figid='fig1')
# plt.pause(0.5)

# html_doc = f'''
# <style type="text/css">
# div#fig1 {{ text-align: center }}
# </style>
#
# {html_fragment}
# '''
#
# Html_file = open("C:/Users/LKJH/Desktop/tttttt.html", "w")
# Html_file.write(html_doc)
# Html_file.close()
# Out:
# Note: if you're in the IPython notebook, mpld3.show() is not the best command
#       to use. Consider using mpld3.display(), or mpld3.enable_notebook().
#       See more information at http://mpld3.github.io/quickstart.html .
#
# You must interrupt the kernel to end this command
#
# Serving to http://127.0.0.1:8889/    [Ctrl-C to exit]
# 127.0.0.1 - - [13/Jul/2023 14:05:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jul/2023 14:05:49] "GET /d3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jul/2023 14:05:49] "GET /mpld3.js HTTP/1.1" 200 -
# stopping Server...

# %%
main_data = pd.DataFrame({'id': [1, 2, 3], 'name': ['jack', 'tom', 'ada']})
child_data= pd.DataFrame({'id': [1, 2], 'game': ['gta1', 'gta2']})
main_data

# %%
child_data.to_dict(orient='records')

# %%
# main_data.loc[main_data['id']==3, 'child_data'] = child_data.to_json(orient='records')
main_data.loc[main_data['id']==3, 'child_data'] = pd.DataFrame({'id':[1,2], 'game': ['gta1', 'gta2']}).to_json(orient='records')

# %%
json_data = main_data.to_json(orient='records')
pd.read_json(json_data)
