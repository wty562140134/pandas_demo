# %%
import numpy as np
import pandas as pd
from pandas import read_sql, DataFrame
from sqlalchemy import create_engine

engine = create_engine(
    'mssql+pyodbc://sa:CgSqlServerRoot2012@172.17.18.110/cgyypt?driver=ODBC+Driver+17+for+SQL+Server')
with engine.connect() as db:
    data = read_sql('select * from wl_dwxx', db)

# %%
data.shape
# Out:
# (6967, 16)

# %%
top_unit:DataFrame = data.loc[data['sjid'] == 0].copy()
unit_child:DataFrame = data.loc[data['sjid'] != 0]
def get_unit_tree(data:DataFrame):
    unit_child_group = data.groupby(by='sjid')
    for k, v in unit_child_group:
        # print('k========',k)
        # print('v========',v['sjid'])

        if not top_unit.loc[top_unit['id'] == k].empty:
            top_unit.loc[top_unit['id'] == k, 'child_data'] = v.to_json(orient='records')


get_unit_tree(unit_child)

# %%
top_unit
# Out:
#                        id  dwlbid  sjid  sfklb  sxs   dwdm               dwmc  \
# 0                       1       2     0    2.0  1.0  02409                陈石春
# 1                       2       2     0    2.0  2.0   9902                李春波
# 2                       3       2     0    2.0  3.0  01003        玉溪市乾鑫矿业有限公司
# 3                       4       2     0    2.0  4.0  01004  江西万舟再生资源有限公司（方永会）
# 4                       5       2     0    2.0  5.0  01005                 昌伟
# ...                   ...     ...   ...    ...  ...    ...                ...
# 6955  1547086240933879808       2     0    NaN  4.0  07024              测试单位8
# 6956  1547086245883158528       2     0    NaN  4.0  07024              测试单位8
# 6957  1547086256834486272       2     0    NaN  4.0  07024              测试单位8
# 6958  1547086260437393408       2     0    NaN  4.0  07024              测试单位8
# 6961  1547755948494430208       2     0    NaN  NaN   None               None
#
# ...

# %%
data['sjid'].value_counts()
# Out:
# 0       5758
# 2130     322
# 4490      41
# 4494      40
# 4491      33
#         ...
# 4565       1
# 4547       1
# 4523       1
# 2074       1
# 1764       1
# Name: sjid, Length: 255, dtype: int64

# %%
group_data = data.groupby('sjid')

# %%
group_keys = group_data.groups.keys()

# %%
k = list(group_keys)

# %%
sj = data.loc[(data['id'].isin(k)) & (data['sjid'] != 0)]
sj
# Out:
#                        id  dwlbid                 sjid  sfklb     sxs   dwdm  \
# 134                   135       2                 1490    2.0   135.0  02072
# 810                   813       1                  833    1.0   813.0  11202
# 815                   818       1                 3343    1.0   818.0  11207
# 990                   994       2                  993    2.0   994.0   1112
# 1588                 1688       2                 1396    2.0  1688.0   1689
# 1691                 1791       2                  135    2.0  1791.0  10551
# 1760                 1861       2                 1471    2.0  1861.0   1861
# 1828                 1955       2                 1954    2.0  1955.0   1955
# 1924                 2067       1                  940    1.0  2067.0   1049
# 1983                 2131       1                 2130    1.0  2131.0   1102
# 1987                 2135       1                 2130    1.0  2135.0  10911
# ...

# %%
sj_group = sj.groupby('sjid')

# %%
sj_group_keys = list(sj_group.groups.keys())

# %%
child_sj = sj.loc[sj['id'].isin(sj_group_keys)]

# %%
child_sj
# Out:
#                        id  dwlbid                 sjid  sfklb     sxs   dwdm  \
# 134                   135       2                 1490    2.0   135.0  02072
# 2000                 2149       1                 2130    1.0  2149.0   2149
# 2012                 2161       1                 2130    1.0  2161.0   2161
# 2015                 2164       1                 2130    1.0  2164.0   2164
# 2551                 2836       1                 2130    1.0  2836.0   2836
# 2941                 3343       1                  817    1.0  3343.0   3343
# 3362                 3813       1                 2130    1.0  3813.0  99142
# 3733                 4232       1                 2130    1.0  4232.0  99279
# 3859                 4369       1                 2130    1.0  4369.0  99342
# 3913                 4424       1                 2130    1.0  4424.0  99376
# 4001                 4518       1                 2130    1.0  4518.0  99425
# ...

# %%
child_group = child_sj.groupby('sjid')

# %%
child_group_keys = list(sj_group.groups.keys())
child_sj.loc[child_sj['id'].isin(child_group_keys)]
# Out:
#                        id  dwlbid                 sjid  sfklb     sxs   dwdm  \
# 134                   135       2                 1490    2.0   135.0  02072
# 2000                 2149       1                 2130    1.0  2149.0   2149
# 2012                 2161       1                 2130    1.0  2161.0   2161
# 2015                 2164       1                 2130    1.0  2164.0   2164
# 2551                 2836       1                 2130    1.0  2836.0   2836
# 2941                 3343       1                  817    1.0  3343.0   3343
# 3362                 3813       1                 2130    1.0  3813.0  99142
# 3733                 4232       1                 2130    1.0  4232.0  99279
# 3859                 4369       1                 2130    1.0  4369.0  99342
# 3913                 4424       1                 2130    1.0  4424.0  99376
# 4001                 4518       1                 2130    1.0  4518.0  99425
# ...
